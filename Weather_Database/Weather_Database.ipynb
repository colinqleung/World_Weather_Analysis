# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | nador
# Processing Record 3 of Set 1 | ilovlya
# Processing Record 4 of Set 1 | marovoay
# Processing Record 5 of Set 1 | rognan
# Processing Record 6 of Set 1 | danilov
# Processing Record 7 of Set 1 | srandakan
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | palu
# Processing Record 14 of Set 1 | noumea
# Processing Record 15 of Set 1 | jinchang
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | yar-sale
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | nome
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | araouane
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | tessalit
# Processing Record 28 of Set 1 | acuna
# City not found. Skipping...
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | itoman
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | nouadhibou
# Processing Record 40 of Set 1 | martapura
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | rovaniemi
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | olafsvik
# Processing Record 45 of Set 1 | saint-michel-des-saints
# Processing Record 46 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | aklavik
# Processing Record 49 of Set 1 | boddam
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 2 | la ronge
# Processing Record 3 of Set 2 | lanzhou
# Processing Record 4 of Set 2 | coos bay
# Processing Record 5 of Set 2 | kedougou
# Processing Record 6 of Set 2 | khanewal
# Processing Record 7 of Set 2 | bubaque
# Processing Record 8 of Set 2 | iwanai
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | burns lake
# Processing Record 11 of Set 2 | pineville
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | buin
# Processing Record 18 of Set 2 | caohai
# Processing Record 19 of Set 2 | ossora
# Processing Record 20 of Set 2 | zhanaozen
# Processing Record 21 of Set 2 | hofn
# Processing Record 22 of Set 2 | kalmunai
# Processing Record 23 of Set 2 | pacific grove
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | lata
# Processing Record 31 of Set 2 | bolshiye uki
# City not found. Skipping...
# Processing Record 32 of Set 2 | springbok
# Processing Record 33 of Set 2 | macas
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | tacuarembo
# Processing Record 37 of Set 2 | magugu
# Processing Record 38 of Set 2 | mount isa
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | maniitsoq
# Processing Record 41 of Set 2 | bekesszentandras
# Processing Record 42 of Set 2 | mount darwin
# Processing Record 43 of Set 2 | carbonia
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | victor harbor
# Processing Record 46 of Set 2 | pokanayevka
# City not found. Skipping...
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | southbridge
# Processing Record 49 of Set 2 | plerin
# Processing Record 50 of Set 2 | ipixuna
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | prince rupert
# Processing Record 4 of Set 3 | kununurra
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | te anau
# Processing Record 8 of Set 3 | rosita
# Processing Record 9 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 3 | turukhansk
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | malanje
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | mus
# Processing Record 15 of Set 3 | raymondville
# Processing Record 16 of Set 3 | kaiu
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | sobradinho
# Processing Record 19 of Set 3 | jumla
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | bilma
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | fukue
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | fairbanks
# Processing Record 27 of Set 3 | neiafu
# Processing Record 28 of Set 3 | alugan
# Processing Record 29 of Set 3 | kudahuvadhoo
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | el sauzal
# Processing Record 32 of Set 3 | saint george
# Processing Record 33 of Set 3 | tual
# Processing Record 34 of Set 3 | hilo
# Processing Record 35 of Set 3 | umea
# Processing Record 36 of Set 3 | mountain home
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | camp verde
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | cap malheureux
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 3 | ponta delgada
# Processing Record 46 of Set 3 | pacifica
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | mpulungu
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | mazagao
# Processing Record 2 of Set 4 | pozo colorado
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | severobaykalsk
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | malindi
# Processing Record 9 of Set 4 | seoul
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | beroroha
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | kloulklubed
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 4 | rosehearty
# Processing Record 19 of Set 4 | ardu
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | coihaique
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | darnah
# Processing Record 25 of Set 4 | taonan
# Processing Record 26 of Set 4 | mehamn
# Processing Record 27 of Set 4 | hami
# Processing Record 28 of Set 4 | killybegs
# Processing Record 29 of Set 4 | diu
# Processing Record 30 of Set 4 | san jeronimo
# Processing Record 31 of Set 4 | tiarei
# Processing Record 32 of Set 4 | manado
# Processing Record 33 of Set 4 | santa vitoria do palmar
# Processing Record 34 of Set 4 | kenai
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | axim
# Processing Record 37 of Set 4 | letlhakane
# Processing Record 38 of Set 4 | yazman
# Processing Record 39 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 40 of Set 4 | cayenne
# Processing Record 41 of Set 4 | sukhumi
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | oranjemund
# Processing Record 44 of Set 4 | takoradi
# Processing Record 45 of Set 4 | balkanabat
# Processing Record 46 of Set 4 | ballina
# Processing Record 47 of Set 4 | stephenville
# Processing Record 48 of Set 4 | abu samrah
# Processing Record 49 of Set 4 | padang
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | chifeng
# Processing Record 2 of Set 5 | klyuchi
# Processing Record 3 of Set 5 | fuerte olimpo
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | roma
# Processing Record 6 of Set 5 | sao geraldo do araguaia
# Processing Record 7 of Set 5 | margate
# Processing Record 8 of Set 5 | peleduy
# Processing Record 9 of Set 5 | sorland
# Processing Record 10 of Set 5 | lakatoro
# Processing Record 11 of Set 5 | asau
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | shieli
# Processing Record 14 of Set 5 | bam
# Processing Record 15 of Set 5 | cambridge
# Processing Record 16 of Set 5 | taunggyi
# Processing Record 17 of Set 5 | sangar
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | marco
# Processing Record 20 of Set 5 | tura
# Processing Record 21 of Set 5 | ati
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | ishigaki
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | jacareacanga
# Processing Record 26 of Set 5 | arman
# Processing Record 27 of Set 5 | wangaratta
# Processing Record 28 of Set 5 | abha
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 5 | sovetskiy
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | fare
# Processing Record 33 of Set 5 | tuktoyaktuk
# Processing Record 34 of Set 5 | kasongo
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 | tokur
# Processing Record 37 of Set 5 | puerto ayora
# Processing Record 38 of Set 5 | el faiyum
# City not found. Skipping...
# Processing Record 39 of Set 5 | saint-pierre
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | saint anthony
# Processing Record 42 of Set 5 | shubarkuduk
# Processing Record 43 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 5 | cockburn town
# Processing Record 45 of Set 5 | matara
# Processing Record 46 of Set 5 | tazovskiy
# Processing Record 47 of Set 5 | saint-augustin
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | ixtapa
# Processing Record 50 of Set 5 | wattegama
# Processing Record 1 of Set 6 | charlottetown
# Processing Record 2 of Set 6 | san policarpo
# Processing Record 3 of Set 6 | northam
# Processing Record 4 of Set 6 | poum
# Processing Record 5 of Set 6 | tyret pervaya
# Processing Record 6 of Set 6 | kiama
# Processing Record 7 of Set 6 | bandarbeyla
# Processing Record 8 of Set 6 | emborion
# Processing Record 9 of Set 6 | shitkino
# Processing Record 10 of Set 6 | khor
# Processing Record 11 of Set 6 | adrar
# Processing Record 12 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 6 | sept-iles
# Processing Record 14 of Set 6 | souillac
# Processing Record 15 of Set 6 | stromness
# Processing Record 16 of Set 6 | maturin
# Processing Record 17 of Set 6 | san javier
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 6 | los llanos de aridane
# Processing Record 21 of Set 6 | la rioja
# Processing Record 22 of Set 6 | wucheng
# Processing Record 23 of Set 6 | itarema
# Processing Record 24 of Set 6 | melton mowbray
# Processing Record 25 of Set 6 | geraldton
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | montepuez
# Processing Record 30 of Set 6 | hokitika
# Processing Record 31 of Set 6 | boone
# Processing Record 32 of Set 6 | morristown
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | kutum
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | wewak
# Processing Record 37 of Set 6 | lons
# Processing Record 38 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 6 | urucara
# Processing Record 40 of Set 6 | tabas
# Processing Record 41 of Set 6 | tabou
# Processing Record 42 of Set 6 | visnes
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | cidreira
# Processing Record 45 of Set 6 | merauke
# Processing Record 46 of Set 6 | basco
# Processing Record 47 of Set 6 | dunedin
# Processing Record 48 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 6 | frontera
# Processing Record 50 of Set 6 | mao
# Processing Record 1 of Set 7 | honningsvag
# Processing Record 2 of Set 7 | chipinge
# Processing Record 3 of Set 7 | sinait
# Processing Record 4 of Set 7 | xai-xai
# Processing Record 5 of Set 7 | krasnoselkup
# Processing Record 6 of Set 7 | podgornoye
# Processing Record 7 of Set 7 | alice springs
# Processing Record 8 of Set 7 | ilo
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | sarangani
# Processing Record 11 of Set 7 | tautira
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | jharsuguda
# Processing Record 14 of Set 7 | vanavara
# Processing Record 15 of Set 7 | kasongo-lunda
# Processing Record 16 of Set 7 | santana do livramento
# Processing Record 17 of Set 7 | dikson
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | at-bashi
# Processing Record 20 of Set 7 | sao joao da barra
# Processing Record 21 of Set 7 | dwarka
# Processing Record 22 of Set 7 | mar del plata
# Processing Record 23 of Set 7 | camacha
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | madarounfa
# Processing Record 26 of Set 7 | plettenberg bay
# Processing Record 27 of Set 7 | port hardy
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | airai
# Processing Record 31 of Set 7 | nanga eboko
# Processing Record 32 of Set 7 | manokwari
# Processing Record 33 of Set 7 | crateus
# Processing Record 34 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint-georges
# Processing Record 37 of Set 7 | beringovskiy
# Processing Record 38 of Set 7 | fort wellington
# Processing Record 39 of Set 7 | megion
# Processing Record 40 of Set 7 | mount gambier
# Processing Record 41 of Set 7 | nhulunbuy
# Processing Record 42 of Set 7 | sawakin
# Processing Record 43 of Set 7 | sassandra
# Processing Record 44 of Set 7 | shizuishan
# Processing Record 45 of Set 7 | kumluca
# Processing Record 46 of Set 7 | el dorado
# Processing Record 47 of Set 7 | iqaluit
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | verkhnevilyuysk
# Processing Record 50 of Set 7 | vila velha
# Processing Record 1 of Set 8 | les cayes
# Processing Record 2 of Set 8 | waverly
# Processing Record 3 of Set 8 | yandyki
# Processing Record 4 of Set 8 | warman
# Processing Record 5 of Set 8 | yarada
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | severo-kurilsk
# Processing Record 8 of Set 8 | kalengwa
# Processing Record 9 of Set 8 | taoudenni
# Processing Record 10 of Set 8 | orzhytsya
# Processing Record 11 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 8 | sri aman
# Processing Record 13 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 8 | atlantic beach
# Processing Record 15 of Set 8 | brigantine
# Processing Record 16 of Set 8 | tema
# Processing Record 17 of Set 8 | sisimiut
# Processing Record 18 of Set 8 | cherskiy
# Processing Record 19 of Set 8 | korla
# Processing Record 20 of Set 8 | honavar
# Processing Record 21 of Set 8 | yumen
# Processing Record 22 of Set 8 | tezu
# Processing Record 23 of Set 8 | lompoc
# Processing Record 24 of Set 8 | floro
# Processing Record 25 of Set 8 | gushikawa
# Processing Record 26 of Set 8 | chateauroux
# Processing Record 27 of Set 8 | qaqortoq
# Processing Record 28 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 29 of Set 8 | neokaisaria
# City not found. Skipping...
# Processing Record 30 of Set 8 | yining
# Processing Record 31 of Set 8 | angoram
# Processing Record 32 of Set 8 | iranshahr
# Processing Record 33 of Set 8 | port blair
# Processing Record 34 of Set 8 | alyangula
# Processing Record 35 of Set 8 | tsiroanomandidy
# Processing Record 36 of Set 8 | yen bai
# Processing Record 37 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 8 | santa isabel do rio negro
# Processing Record 39 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 40 of Set 8 | bure
# Processing Record 41 of Set 8 | acapulco
# Processing Record 42 of Set 8 | burkhala
# City not found. Skipping...
# Processing Record 43 of Set 8 | chicama
# Processing Record 44 of Set 8 | moree
# Processing Record 45 of Set 8 | hanzhong
# Processing Record 46 of Set 8 | avera
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | coueron
# Processing Record 49 of Set 8 | richards bay
# Processing Record 50 of Set 8 | zaraza
# Processing Record 1 of Set 9 | cabo san lucas
# Processing Record 2 of Set 9 | fernley
# Processing Record 3 of Set 9 | nizhneangarsk
# Processing Record 4 of Set 9 | mulanje
# Processing Record 5 of Set 9 | novobessergenevka
# Processing Record 6 of Set 9 | matagami
# Processing Record 7 of Set 9 | ayios matthaios
# City not found. Skipping...
# Processing Record 8 of Set 9 | north bend
# Processing Record 9 of Set 9 | waverley
# Processing Record 10 of Set 9 | klaksvik
# Processing Record 11 of Set 9 | san patricio
# Processing Record 12 of Set 9 | sengiley
# Processing Record 13 of Set 9 | nelson bay
# Processing Record 14 of Set 9 | augusto correa
# Processing Record 15 of Set 9 | zelenoborskiy
# Processing Record 16 of Set 9 | bela vista
# Processing Record 17 of Set 9 | iracoubo
# Processing Record 18 of Set 9 | manta
# Processing Record 19 of Set 9 | zhigansk
# Processing Record 20 of Set 9 | gat
# Processing Record 21 of Set 9 | esmeraldas
# Processing Record 22 of Set 9 | steamboat springs
# Processing Record 23 of Set 9 | talin
# Processing Record 24 of Set 9 | the pas
# Processing Record 25 of Set 9 | faanui
# Processing Record 26 of Set 9 | dobarceni
# Processing Record 27 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 9 | prieska
# Processing Record 30 of Set 9 | gigmoto
# Processing Record 31 of Set 9 | oeiras
# Processing Record 32 of Set 9 | piriyapatna
# Processing Record 33 of Set 9 | hof
# Processing Record 34 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 36 of Set 9 | buique
# Processing Record 37 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 9 | horadiz
# Processing Record 39 of Set 9 | hohhot
# Processing Record 40 of Set 9 | praia
# Processing Record 41 of Set 9 | roald
# Processing Record 42 of Set 9 | russell
# Processing Record 43 of Set 9 | uvinza
# Processing Record 44 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 9 | saint-joseph
# Processing Record 46 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 9 | abomsa
# Processing Record 48 of Set 9 | camocim
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | hirara
# Processing Record 2 of Set 10 | old town
# Processing Record 3 of Set 10 | clyde river
# Processing Record 4 of Set 10 | arlit
# Processing Record 5 of Set 10 | alvorada
# Processing Record 6 of Set 10 | ortigueira
# Processing Record 7 of Set 10 | khromtau
# Processing Record 8 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 10 | bobo dioulasso
# Processing Record 10 of Set 10 | wajima
# Processing Record 11 of Set 10 | tranas
# Processing Record 12 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 13 of Set 10 | naqadeh
# Processing Record 14 of Set 10 | kaeo
# Processing Record 15 of Set 10 | agadez
# Processing Record 16 of Set 10 | sinnamary
# Processing Record 17 of Set 10 | ilhabela
# Processing Record 18 of Set 10 | charlotte
# Processing Record 19 of Set 10 | kiunga
# Processing Record 20 of Set 10 | kurchum
# Processing Record 21 of Set 10 | vanimo
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | morehead
# Processing Record 24 of Set 10 | nanortalik
# Processing Record 25 of Set 10 | bajil
# Processing Record 26 of Set 10 | tiksi
# Processing Record 27 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 10 | ruwi
# Processing Record 29 of Set 10 | bushenyi
# Processing Record 30 of Set 10 | santa luzia
# Processing Record 31 of Set 10 | ejea de los caballeros
# Processing Record 32 of Set 10 | havoysund
# Processing Record 33 of Set 10 | genhe
# Processing Record 34 of Set 10 | morant bay
# Processing Record 35 of Set 10 | narsaq
# Processing Record 36 of Set 10 | beidao
# Processing Record 37 of Set 10 | chapais
# Processing Record 38 of Set 10 | saint andrews
# Processing Record 39 of Set 10 | twentynine palms
# Processing Record 40 of Set 10 | burla
# Processing Record 41 of Set 10 | traverse city
# Processing Record 42 of Set 10 | nagapattinam
# Processing Record 43 of Set 10 | tupancireta
# Processing Record 44 of Set 10 | mumbwa
# Processing Record 45 of Set 10 | saldanha
# Processing Record 46 of Set 10 | college
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 10 | amapa
# Processing Record 50 of Set 10 | quatre cocos
# Processing Record 1 of Set 11 | coalcoman
# City not found. Skipping...
# Processing Record 2 of Set 11 | lahij
# Processing Record 3 of Set 11 | portland
# Processing Record 4 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 11 | kisanga
# Processing Record 6 of Set 11 | grand gaube
# Processing Record 7 of Set 11 | bodden town
# Processing Record 8 of Set 11 | serafimovich
# Processing Record 9 of Set 11 | olavarria
# Processing Record 10 of Set 11 | talcahuano
# Processing Record 11 of Set 11 | atasu
# Processing Record 12 of Set 11 | yeniseysk
# Processing Record 13 of Set 11 | laguna
# Processing Record 14 of Set 11 | keshan
# City not found. Skipping...
# Processing Record 15 of Set 11 | brae
# Processing Record 16 of Set 11 | gunnedah
# Processing Record 17 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 11 | stawell
# Processing Record 19 of Set 11 | pasighat
# Processing Record 20 of Set 11 | waingapu
# Processing Record 21 of Set 11 | jimeta
# Processing Record 22 of Set 11 | gizo
# Processing Record 23 of Set 11 | pringsewu
# Processing Record 24 of Set 11 | sajanan
# Processing Record 25 of Set 11 | bairiki
# Processing Record 26 of Set 11 | san quintin
# Processing Record 27 of Set 11 | namibe
# Processing Record 28 of Set 11 | batman
# Processing Record 29 of Set 11 | lapy
# Processing Record 30 of Set 11 | shahreza
# Processing Record 31 of Set 11 | xining
# Processing Record 32 of Set 11 | sao jose da coroa grande
# Processing Record 33 of Set 11 | soyo
# Processing Record 34 of Set 11 | mangrol
# Processing Record 35 of Set 11 | yerbogachen
# Processing Record 36 of Set 11 | wilmington
# Processing Record 37 of Set 11 | novoagansk
# Processing Record 38 of Set 11 | sundsvall
# Processing Record 39 of Set 11 | bosaso
# Processing Record 40 of Set 11 | bhuj
# Processing Record 41 of Set 11 | gawler
# Processing Record 42 of Set 11 | egvekinot
# Processing Record 43 of Set 11 | pochutla
# Processing Record 44 of Set 11 | zacualtipan
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | mandalgovi
# Processing Record 48 of Set 11 | leningradskiy
# Processing Record 49 of Set 11 | qiongshan
# Processing Record 50 of Set 11 | abu kamal
# Processing Record 1 of Set 12 | nara
# Processing Record 2 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 12 | port hope
# Processing Record 4 of Set 12 | posse
# Processing Record 5 of Set 12 | tecoanapa
# Processing Record 6 of Set 12 | kauhajoki
# Processing Record 7 of Set 12 | utica
# Processing Record 8 of Set 12 | markdale
# Processing Record 9 of Set 12 | divnomorskoye
# Processing Record 10 of Set 12 | finnsnes
# Processing Record 11 of Set 12 | east stroudsburg
# Processing Record 12 of Set 12 | yaan
# Processing Record 13 of Set 12 | thika
# Processing Record 14 of Set 12 | neya
# Processing Record 15 of Set 12 | kpagouda
# City not found. Skipping...
# Processing Record 16 of Set 12 | sandwick
# Processing Record 17 of Set 12 | mackay
# Processing Record 18 of Set 12 | chuchkovo
# Processing Record 19 of Set 12 | zharkent
# Processing Record 20 of Set 12 | jaca
# Processing Record 21 of Set 12 | santa maria
# Processing Record 22 of Set 12 | beckley
# Processing Record 23 of Set 12 | vila franca do campo
# Processing Record 24 of Set 12 | naze
# Processing Record 25 of Set 12 | andenes
# Processing Record 26 of Set 12 | mulege
# Processing Record 27 of Set 12 | karonga
# Processing Record 28 of Set 12 | casas grandes
# Processing Record 29 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 30 of Set 12 | padre bernardo
# Processing Record 31 of Set 12 | ignatovka
# Processing Record 32 of Set 12 | omsukchan
# Processing Record 33 of Set 12 | pilot butte
# Processing Record 34 of Set 12 | chara
# Processing Record 35 of Set 12 | nemuro
# Processing Record 36 of Set 12 | palamos
# Processing Record 37 of Set 12 | mollendo
# Processing Record 38 of Set 12 | labuhan
# Processing Record 39 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 12 | lasa
# Processing Record 41 of Set 12 | half moon bay
# Processing Record 42 of Set 12 | maryville
# Processing Record 43 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 44 of Set 12 | vincennes
# Processing Record 45 of Set 12 | samdari
# Processing Record 46 of Set 12 | svetlogorsk
# Processing Record 47 of Set 12 | unye
# City not found. Skipping...
# Processing Record 48 of Set 12 | bethanien
# Processing Record 49 of Set 12 | touros
# Processing Record 50 of Set 12 | ipameri
# Processing Record 1 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 13 | maun
# Processing Record 3 of Set 13 | gewane
# Processing Record 4 of Set 13 | icod de los vinos
# Processing Record 5 of Set 13 | porto velho
# Processing Record 6 of Set 13 | ondjiva
# Processing Record 7 of Set 13 | karasuk
# Processing Record 8 of Set 13 | broome
# Processing Record 9 of Set 13 | kosa
# Processing Record 10 of Set 13 | felipe carrillo puerto
# Processing Record 11 of Set 13 | hobyo
# Processing Record 12 of Set 13 | komsomolskiy
# Processing Record 13 of Set 13 | puerto narino
# Processing Record 14 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 13 | ozernovskiy
# Processing Record 16 of Set 13 | sorong
# Processing Record 17 of Set 13 | ternate
# Processing Record 18 of Set 13 | kavieng
# Processing Record 19 of Set 13 | alta gracia
# Processing Record 20 of Set 13 | nakhodka
# Processing Record 21 of Set 13 | qingdao
# Processing Record 22 of Set 13 | cap-aux-meules
# Processing Record 23 of Set 13 | mocuba
# Processing Record 24 of Set 13 | porto novo
# Processing Record 25 of Set 13 | constitucion
# Processing Record 26 of Set 13 | fulacunda
# City not found. Skipping...
# Processing Record 27 of Set 13 | boguchany
# Processing Record 28 of Set 13 | monte cristi
# City not found. Skipping...
# Processing Record 29 of Set 13 | vangaindrano
# Processing Record 30 of Set 13 | chute-aux-outardes
# Processing Record 31 of Set 13 | zhicheng
# Processing Record 32 of Set 13 | hoquiam
# Processing Record 33 of Set 13 | sena madureira
# Processing Record 34 of Set 13 | teno
# Processing Record 35 of Set 13 | miri
# Processing Record 36 of Set 13 | yei
# Processing Record 37 of Set 13 | campbeltown
# Processing Record 38 of Set 13 | awjilah
# Processing Record 39 of Set 13 | lamu
# Processing Record 40 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 13 | toora-khem
# Processing Record 42 of Set 13 | maceio
# Processing Record 43 of Set 13 | khingansk
# Processing Record 44 of Set 13 | nioro
# Processing Record 45 of Set 13 | ancud
# Processing Record 46 of Set 13 | isiro
# Processing Record 47 of Set 13 | sao sepe
# Processing Record 48 of Set 13 | athens
# Processing Record 49 of Set 13 | herzberg
# Processing Record 50 of Set 13 | betioky
# Processing Record 1 of Set 14 | sioux lookout
# Processing Record 2 of Set 14 | craig
# Processing Record 3 of Set 14 | yulara
# Processing Record 4 of Set 14 | shakawe
# Processing Record 5 of Set 14 | saint-francois
# Processing Record 6 of Set 14 | husavik
# Processing Record 7 of Set 14 | havre-saint-pierre
# Processing Record 8 of Set 14 | bayshore gardens
# Processing Record 9 of Set 14 | yilan
# Processing Record 10 of Set 14 | teguldet
# Processing Record 11 of Set 14 | tsabong
# Processing Record 12 of Set 14 | kitimat
# Processing Record 13 of Set 14 | elko
# Processing Record 14 of Set 14 | nizhniy kuranakh
# Processing Record 15 of Set 14 | petukhovo
# Processing Record 16 of Set 14 | hoopstad
# Processing Record 17 of Set 14 | chastoozerye
# City not found. Skipping...
# Processing Record 18 of Set 14 | rzhev
# Processing Record 19 of Set 14 | zarubino
# Processing Record 20 of Set 14 | kirkenes
# Processing Record 21 of Set 14 | san vicente de canete
# Processing Record 22 of Set 14 | nongan
# Processing Record 23 of Set 14 | berlevag
# Processing Record 24 of Set 14 | agirish
# Processing Record 25 of Set 14 | hambantota
# Processing Record 26 of Set 14 | turtas
# Processing Record 27 of Set 14 | rota
# Processing Record 28 of Set 14 | guantanamo
# Processing Record 29 of Set 14 | novyy urengoy
# Processing Record 30 of Set 14 | isangel
# Processing Record 31 of Set 14 | kamiiso
# Processing Record 32 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 14 | trelew
# Processing Record 34 of Set 14 | dickson
# Processing Record 35 of Set 14 | lagos
# Processing Record 36 of Set 14 | shenjiamen
# Processing Record 37 of Set 14 | clarence town
# Processing Record 38 of Set 14 | kita
# Processing Record 39 of Set 14 | ketchikan
# Processing Record 40 of Set 14 | batemans bay
# Processing Record 41 of Set 14 | soto la marina
# Processing Record 42 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | haines junction
# Processing Record 44 of Set 14 | toowoomba
# Processing Record 45 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 14 | parana
# Processing Record 47 of Set 14 | zhangye
# Processing Record 48 of Set 14 | garowe
# Processing Record 49 of Set 14 | constantine
# Processing Record 50 of Set 14 | nayoro
# Processing Record 1 of Set 15 | scarborough
# Processing Record 2 of Set 15 | karratha
# Processing Record 3 of Set 15 | kinston
# Processing Record 4 of Set 15 | hay river
# Processing Record 5 of Set 15 | san nicolas
# Processing Record 6 of Set 15 | polovinnoye
# Processing Record 7 of Set 15 | bonthe
# Processing Record 8 of Set 15 | lodja
# Processing Record 9 of Set 15 | lerwick
# Processing Record 10 of Set 15 | akdepe
# Processing Record 11 of Set 15 | kulim
# Processing Record 12 of Set 15 | lapa
# Processing Record 13 of Set 15 | chumikan
# Processing Record 14 of Set 15 | byron bay
# Processing Record 15 of Set 15 | rudnogorsk
# Processing Record 16 of Set 15 | lahan
# Processing Record 17 of Set 15 | rudbar
# Processing Record 18 of Set 15 | ginda
# Processing Record 19 of Set 15 | teya
# Processing Record 20 of Set 15 | tanout
# Processing Record 21 of Set 15 | yuzhou
# Processing Record 22 of Set 15 | batagay
# Processing Record 23 of Set 15 | sosua
# Processing Record 24 of Set 15 | boa vista
# Processing Record 25 of Set 15 | presque isle
# Processing Record 26 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 27 of Set 15 | horsham
# Processing Record 28 of Set 15 | balykshi
# Processing Record 29 of Set 15 | altagracia de orituco
# Processing Record 30 of Set 15 | waitati
# Processing Record 31 of Set 15 | palmer
# Processing Record 32 of Set 15 | hlobyne
# Processing Record 33 of Set 15 | marsa matruh
# Processing Record 34 of Set 15 | sabang
# Processing Record 35 of Set 15 | luena
# Processing Record 36 of Set 15 | aquiraz
# Processing Record 37 of Set 15 | along
# Processing Record 38 of Set 15 | ulaangom
# Processing Record 39 of Set 15 | kisaran
# Processing Record 40 of Set 15 | coro
# Processing Record 41 of Set 15 | cansancao
# Processing Record 42 of Set 15 | okhotsk
# Processing Record 43 of Set 15 | bowen
# Processing Record 44 of Set 15 | wadi musa
# Processing Record 45 of Set 15 | dzerzhinskoye
# Processing Record 46 of Set 15 | wanaka
# Processing Record 47 of Set 15 | salinopolis
# Processing Record 48 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 49 of Set 15 | hovd
# Processing Record 50 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 16 | akyab
# Processing Record 2 of Set 16 | huarmey
# Processing Record 3 of Set 16 | playas
# Processing Record 4 of Set 16 | hualmay
# Processing Record 5 of Set 16 | jijiga
# Processing Record 6 of Set 16 | bella union

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus -34.4187   19.2345     57.47        76           0
# 1         Nador  35.1740   -2.9287     61.05        82          40
# 2       Ilovlya  49.3033   43.9796     65.16        52         100
# 3      Marovoay -16.1000   46.6333     79.07        71          73
# 4        Rognan  67.0953   15.3878     30.34        80         100
# 5       Danilov  58.1908   40.1717     37.92        97          63
# 6     Srandakan  -7.9386  110.2506     76.75        90          91
# 7         Vaini -21.2000 -175.2000     77.16        69          20
# 8   Port Alfred -33.5906   26.8910     58.17        91          10
# 9  Punta Arenas -53.1500  -70.9167     41.11        65          40
#
#    Wind Speed Country                 Date
# 0        8.72      ZA  2022-04-26 21:15:23
# 1        3.44      MA  2022-04-26 21:17:52
# 2        8.16      RU  2022-04-26 21:17:53
# 3        2.64      MG  2022-04-26 21:17:53
# 4        4.29      NO  2022-04-26 21:17:54
# 5        4.70      RU  2022-04-26 21:17:54
# 6        3.87      ID  2022-04-26 21:17:54
# 7       11.50      TO  2022-04-26 21:17:55
# 8        4.00      ZA  2022-04-26 21:17:55
# 9        5.75      CL  2022-04-26 21:14:01

# %%
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
order_df = city_data_df[new_column_order]
order_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     57.47        76           0
# 1         Nador      MA  35.1740   -2.9287     61.05        82          40
# 2       Ilovlya      RU  49.3033   43.9796     65.16        52         100
# 3      Marovoay      MG -16.1000   46.6333     79.07        71          73
# 4        Rognan      NO  67.0953   15.3878     30.34        80         100
# 5       Danilov      RU  58.1908   40.1717     37.92        97          63
# 6     Srandakan      ID  -7.9386  110.2506     76.75        90          91
# 7         Vaini      TO -21.2000 -175.2000     77.16        69          20
# 8   Port Alfred      ZA -33.5906   26.8910     58.17        91          10
# 9  Punta Arenas      CL -53.1500  -70.9167     41.11        65          40
#
#    Wind Speed
# 0        8.72
# 1        3.44
# 2        8.16
# 3        2.64
# 4        4.29
# 5        4.70
# 6        3.87
# 7       11.50
# 8        4.00
# 9        5.75

# %%
# Create the output file (CSV).
output_data_file = "WeatherPY_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
